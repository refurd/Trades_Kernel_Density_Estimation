# %% [markdown]
# # Adatok kijelzése grafikonon

# %% [markdown]
# ### Importálások

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

# %% [markdown]
# ### Beolvassuk a CSV-t

# %%
df_raw = pd.read_csv(r'C:\Users\Dominik\Desktop\GYORKOS\Data\Stocks\TEVA.csv')

# %%
df_raw.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2016-01-19  62.740002  63.380001  61.500000  62.090000  58.392120  5739000
# 1  2016-01-20  61.090000  62.540001  59.939999  61.880001  58.194626  6059200
# 2  2016-01-21  61.980000  62.349998  60.880001  61.990002  58.298080  4132800
# 3  2016-01-22  62.680000  63.279999  61.970001  63.259998  59.492439  4288600
# 4  2016-01-25  63.150002  64.309998  62.709999  63.169998  59.407799  3295000

# %%
df.plot(x="Date", y="Open")

# %%
df_raw.plot(x="Date", y="Volume")

# %% [markdown]
# ### Egy táblázatba hozzuk az adatokat. Open - Max - Min - Close.

# %% [markdown]
# ##### Betöltjük egy táblába a dátumot és az adatokat egymás után

# %%
df_Date = []
for x in range(0, len(df_raw)):
    for y in range (0,4):
        df_Date.append(df_raw.iat[x,0])
df_Value = []
for x in range(0, len(df_raw)):
    for y in range (1,5):
        df_Value.append(df_raw.iat[x,y])

# %% [markdown]
# ##### Létrehozzuk az új df-et

# %%
data = {'date':df_Date, 'stock1':df_Value}
df = pd.DataFrame(data)
df.head(10)
# Out:
#          date     stock1
# 0  2016-01-19  62.740002
# 1  2016-01-19  63.380001
# 2  2016-01-19  61.500000
# 3  2016-01-19  62.090000
# 4  2016-01-20  61.090000
# 5  2016-01-20  62.540001
# 6  2016-01-20  59.939999
# 7  2016-01-20  61.880001
# 8  2016-01-21  61.980000
# 9  2016-01-21  62.349998

# %% [markdown]
# ### Adat ellenőrzés

# %%
df.iloc[1,1]
# Out:
# 63.380001

# %%
df.isnull().sum()
# Out:
# date      0
# stock1    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5036 entries, 0 to 5035
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    5036 non-null   object
#  1   stock1  5036 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 78.8+ KB

# %%
df.plot()
